# %% [markdown]
# VISUALIZING BCI CENSUS DATA!

# %%
import numpy as np
import pandas as pd

# %%
bci = pd.read_csv("bci_1982.csv")
pd.set_option("display.max.columns", None)
bci.head(50)
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (14,16) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#     Unnamed: 0  treeID  stemID    tag  StemTag      sp  quadrat          gx  \
# 0            1       1     1.0  -5599      NaN  swars1   4007.0  800.200012
# 1            2       2     1.0 -22851      NaN  hybapr    718.0  151.500000
# 2            3       3     1.0 -24362      NaN  aegipa    417.0   95.199997
# 3            4       4     NaN -26589      NaN  beilpe      7.0   11.700000
# 4            5       5     NaN -26590      NaN  faraoc      4.0    7.700000
# 5            6       6     NaN -26703      NaN  hybapr    210.0   50.099998
# 6            7       7     NaN -26746      NaN  tet2pa    218.0   58.500000
# 7            8       8     NaN -27125      NaN  des2pa    613.0  139.800003
# ...

# %%
bci.plot(x='gx', y='gy', )
# Out:
# <AxesSubplot:xlabel='gx'>

# %%
bci.dbh.plot()
# Out:
# <AxesSubplot:>

# %%
bci.dbh.max()
# Out:
# 3500.0

# %%
bci.dbh.min()
# Out:
# 10.0

# %%
bci.dbh.idxmax()
# Out:
# 725

# %%
bci.dbh.idxmin()
# Out:
# 2
